# %% [markdown]
# # Project 3 -- Muhammad Rizwan

# %% [markdown]
# **TA Help:** John Smith, Alice Jones
#
# - Help with figuring out how to write a function.
#
# **Collaboration:** Friend1, Friend2
#
# - Helped figuring out how to load the dataset.
# - Helped debug error with my plot.

# %% [markdown]
# ## Question 1

# %%
library(data.table) # importing the data table package 
myDF <- fread("/anvil/projects/tdm/data/flights/subset/1990.csv") # importing the 1990 flights CSV file

# %%
tapply(myDF$ArrDelay, myDF$Dest, mean, na.rm=TRUE) # finding the average arrival delay time based off destination
# Out:
#         ABE         ABQ         ACY         AGS         ALB         AMA
#   4.7749400   7.7720134   5.5880759   8.3583853   7.5112601   8.5679871
#         ANC         ATL         ATW         AUS         AVL         AVP
#  11.3615363   8.5970350 -11.2530120   6.2188843   5.5619174   7.2391017
#         AZO         BDL         BET         BFL         BGM         BGR
#   3.3342525   7.5015869  11.8017544   5.7055990   4.6090188  11.6194061
#         BHM         BIL         BIS         BLI         BNA         BOI
#   5.6182156   4.3069083   4.3256917   6.5716630   2.9905406   7.8021441
#         BOS         BTM         BTR         BTV         BUF         BUR
#   8.6813895   6.1114327   7.7275846   7.1847366   7.6238587   2.9779121
#         BWI         BZN         CAE         CAK         CCR         CDV
#   6.1178011   6.0083052   8.4543987   5.6934813   1.0583596   8.3764881
#         CHA         CHO         CHS         CID         CLE         CLT
# ...

# %% [markdown]
# Here, I imported the dataset into the Jupyter Notebook and then found the average arrival delay time based on destination through the use of the apply function.

# %% [markdown]
# ## Question 2

# %%
library(data.table) # importing the data table package 
myDF <- fread("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv", quote="") # importing the grocery store CSV file

# %%
tapply(myDF$SPEND, myDF$STORE_R, sum) # using the tapply function to find the sum of spending per region
# Out:
#  CENTRAL     EAST    SOUTH     WEST
#  8897305 11699447  7957921  9680107

# %% [markdown]
# Here I imported the dataset into Jupyter then used the tapply function to find the sum of spending for every store in the 4 different regions.

# %% [markdown]
# ## Question 3

# %%
library(data.table) # importing the data table package 
myDF <- fread("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv") # importing the grocery store CSV file

# %%
tapply(myDF$SPEND, myDF$YEAR, sum) # using the tapply function to find the sum of spending per year
# Out:
#     2016     2017
# 19051720 19183059

# %% [markdown]
# Here I imported the dataset into Jupyter then used the tapply function to find the sum of spending per year at this grocery store.

# %% [markdown]
# ## Question 4

# %%
library(data.table) # importing the data table package
myDF <- fread("/anvil/projects/tdm/data/olympics/athlete_events.csv") # importing the Olympic Athlete Events CSV file

# %%
mean(myDF$Height, na.rm=TRUE) # using the mean function to find the average height of all olympic athletes in the dataset
# Out:
# [1] 175.339

# %% [markdown]
# Here I imported the dataset into Jupyter then used the mean function to find the average height of all olympic athletes in the dataset.

# %% [markdown]
# ## Question 5

# %%
library(data.table) # importing the data table package
myDF <- fread("/anvil/projects/tdm/data/olympics/athlete_events.csv") # importing the Olympic Athlete Events CSV file

# %%
tapply(myDF$Height, myDF$Sport, mean, na.rm=TRUE) # using the tapply function to find the average height of olympic athletes by sport
# Out:
#               Aeronautics             Alpine Skiing                  Alpinism
#                       NaN                  173.4891                       NaN
#                   Archery          Art Competitions                 Athletics
#                  173.2031                  174.6441                  176.2563
#                 Badminton                  Baseball                Basketball
#                  174.1788                  182.5993                  190.8699
#             Basque Pelota          Beach Volleyball                  Biathlon
#                       NaN                  186.1450                  174.0348
#                 Bobsleigh                    Boxing                  Canoeing
#                  181.4375                  172.8257                  178.5396
#                   Cricket                   Croquet      Cross Country Skiing
#                       NaN                       NaN                  173.2492
# ...

# %% [markdown]
# Here, I imported the dataset into Jupyter and then used the mean function to find the average height of Olympic athletes by sport in the dataset. The highest average height of a single sport out of this dataset is for basketball, with the average being 190.869878897191. This makes sense as basketball is generally considered a sport where height is needed and usually does have the tallest people in the world playing it.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
